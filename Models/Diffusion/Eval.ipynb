# %%
import os
import sys
import shlex

commandline_args = os.environ.get('COMMANDLINE_ARGS', "")
commandline_args = os.environ.get('COMMANDLINE_ARGS', "--skip-torch-cuda-test --no-half")
sys.argv += shlex.split(commandline_args)

# os.environ["COMMANDLINE_ARGS"] = "--skip-torch-cuda-test --precision full --no-half"

# %%
import torch
from diffusers import AutoPipelineForText2Image

# %%
pipeline = AutoPipelineForText2Image.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float32, variant="fp16")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.

# %%
image = pipeline("dumb CEO and dumber managers around him, detailed").images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from Generation_StableDiff import TextToImage

MyTextToImage = TextToImage(model = 'stable-diffusion-v1-5', image_size = 512, to_cuda = False)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.

# %%
img = MyTextToImage.generation('یک دختر زیبا با لباس سبز که در حال نوشتن است و چای او روی میزش می باشد، با جزئیات واقعی')
img
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
